# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopal-krushna-maharana2004/codomax/blob/main/TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Day 1 - Data Science Environment Setup
Author: Gopal Krushna Maharana
"""

def welcome():
    print("=" * 50)
    print("Welcome to Data Science with Python!")
    print("=" * 50)
    print("Hello, Gopal Krushna Maharana")
    print("Development Environment Successfully Configured")
    print("\nInstalled Tools:")
    tools = [
        "Python",
        "VS Code",
        "Jupyter Notebook",
        "Git",
        "GitHub"
    ]

    for tool in tools:
        print(f"✔ {tool}")

    print("\nFirst Python Program Executed Successfully!")
    print("Ready to begin Data Science Journey ")


if __name__ == "__main__":
    welcome()
# Out:
# ...
# Welcome to Data Science with Python!
# ...
# Hello, Gopal Krushna Maharana
# Development Environment Successfully Configured
#
# Installed Tools:
# ✔ Python
# ✔ VS Code
# ✔ Jupyter Notebook
# ✔ Git
# ✔ GitHub
#
# First Python Program Executed Successfully!
# Ready to begin Data Science Journey 🚀
